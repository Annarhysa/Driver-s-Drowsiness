# %%
import numpy as np
import pandas as pd
import cv2
import os
import matplotlib.pyplot as plt

# %%
labels = ['Closed', 'no_yawn', 'Open', 'yawn']

# %%
plt.imshow(plt.imread("./Data/yawn/1.jpg"))

# %%
x = plt.imread("./Data/yawn/1.jpg")
x.shape
# Out:
# (480, 640, 3)

# %%
def face_for_yawn():
    direc = "C:/Users/annar/OneDrive/Desktop/Visual Studio/GitHub/Projects3/Drivers-Drowsiness/Data/train"
    face_cas_path = "C:/Users/annar/OneDrive/Desktop/Visual Studio/GitHub/Projects3/Drivers-Drowsiness/Data/predicition/haarcascade_frontalface_default.xml"
    yaw_no = []
    IMG_SIZE = 145
    categories = ["yawn", "no_yawn"]
    for category in categories:
        path_link = os.path.join(direc, category)
        class_num1 = categories.index(category)
        print(class_num1)
        for image in os.listdir(path_link):
            image_array = cv2.imread(os.path.join(path_link, image), cv2.IMREAD_COLOR)
            face_cascade = cv2.CascadeClassifier(face_cas_path)
            faces = face_cascade.detectMultiScale(image_array, 1.3, 5)
            for (x, y, w, h) in faces:
                img = cv2.rectangle(image_array, (x, y), (x+w, y+h), (0, 255, 0), 2)
                roi_color = img[y:y+h, x:x+w]
                resized_array = cv2.resize(roi_color, (IMG_SIZE, IMG_SIZE))
                yaw_no.append([resized_array, class_num1])
    return yaw_no


yawn_no_yawn = face_for_yawn()
# Out:
# 0
# 1
